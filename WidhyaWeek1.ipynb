# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from warnings import filterwarnings

# %%
data=pd.read_csv('https://raw.githubusercontent.com/WidhyaOrg/datasets/master/bitcoin_dataset.csv')

# %%
data.head()
# Out:
#         Date  ...  btc_estimated_transaction_volume_usd
# 0  2/17/2010  ...                                   0.0
# 1  2/18/2010  ...                                   0.0
# 2  2/19/2010  ...                                   0.0
# 3  2/20/2010  ...                                   0.0
# 4  2/21/2010  ...                                   0.0
#
# [5 rows x 24 columns]

# %%
data.iloc[1023, 1]
# Out:
# 13.6888

# %%
cols=['Date','btc_total_bitcoins','btc_trade_volume','btc_blocks_size','btc_avg_block_size','btc_n_orphaned_blocks','btc_n_transactions_per_block','btc_median_confirmation_time','btc_transaction_fees','btc_n_unique_addresses','btc_n_transactions_total','btc_n_transactions_excluding_popular','btc_n_transactions_excluding_chains_longer_than_100','btc_output_volume','btc_estimated_transaction_volume','btc_estimated_transaction_volume_usd']
df2=data.drop(cols,axis=1,inplace=True)

# %%
data.head()
# Out:
#    btc_market_price  ...  btc_n_transactions
# 0               0.0  ...                 244
# 1               0.0  ...                 235
# 2               0.0  ...                 183
# 3               0.0  ...                 224
# 4               0.0  ...                 218
#
# [5 rows x 8 columns]

# %%
total=data.isnull().sum()
print(total)
# Out:
# btc_market_price                     0
# btc_market_cap                       0
# btc_hash_rate                        0
# btc_difficulty                      16
# btc_miners_revenue                   0
# btc_cost_per_transaction_percent     0
# btc_cost_per_transaction             0
# btc_n_transactions                   0
# dtype: int64

# %%
 data['btc_difficulty'].fillna(value=data['btc_difficulty'].mean(), inplace=True)

# %%
y= data.iloc[:,0]
X=data.iloc[:,1:]
print(y)
# Out:
# 0           0.00000
# 1           0.00000
# 2           0.00000
# 3           0.00000
# 4           0.00000
#            ...
# 2901    11524.77667
# 2902    11765.71000
# 2903    11212.65500
# 2904    10184.06167
# 2905    10125.01333
# Name: btc_market_price, Length: 2906, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %%
y_train.shape
# Out:
# (2324,)

# %%
y_Train=y_train.values

# %%
y_Train.reshape(2324,1)
# Out:
# array([[6.68890000e-02],
#        [1.11869000e+01],
#        [2.73950000e+02],
#        ...,
#        [5.09390000e+02],
#        [1.18114984e+03],
#        [3.63250667e+03]])

# %%
X_Train=X_train.values

# %%
X_Train.shape
# Out:
# (2324, 7)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_Train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=regressor.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 439.0555907485371
